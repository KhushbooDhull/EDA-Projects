# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Coffee Dataset EDA Project
# ### Coffee_EDA_Questions

# %% [markdown]
# #### 1) Read the dataset

# %%
df= pd.read_csv('Coffee.csv')
df.head(10)
# Out:
#    Area Code   Date   Market   Market Size            Product Product Line  \
# 0        719  40909  Central  Major Market           Amaretto        Beans
# 1        970  40909  Central  Major Market          Colombian        Beans
# 2        970  40909  Central  Major Market  Decaf Irish Cream        Beans
# 3        303  40909  Central  Major Market          Green Tea       Leaves
# 4        303  40909  Central  Major Market        Caffe Mocha        Beans
# 5        720  40909  Central  Major Market     Decaf Espresso        Beans
# 6        970  40909  Central  Major Market          Chamomile       Leaves
# 7        719  40909  Central  Major Market              Lemon       Leaves
# 8        970  40909  Central  Major Market               Mint       Leaves
# 9        719  40909  Central  Major Market         Darjeeling       Leaves
#
#   Product Type     State     Type  Budget COGS  Budget Margin  Budget Profit  \
# ...

# %%
df.describe()
# Out:
#          Area Code          Date  Budget COGS  Budget Margin  Budget Profit  \
# count  4248.000000   4248.000000  4248.000000    4248.000000    4248.000000
# mean    582.278013  41258.916667    74.830508     100.819209      60.913371
# std     221.140310    210.712945    66.238145      92.602725      79.546123
# min     203.000000  40909.000000     0.000000    -210.000000    -320.000000
# 25%     417.000000  41083.500000    30.000000      50.000000      20.000000
# 50%     573.000000  41259.500000    50.000000      70.000000      40.000000
# 75%     772.000000  41433.500000    90.000000     130.000000      80.000000
# max     985.000000  41609.000000   450.000000     690.000000     560.000000
#
#        Budget Sales         COGS    Inventory       Margin    Marketing  \
# count   4248.000000  4248.000000  4248.000000  4248.000000  4248.000000
# mean     175.649718    84.433145   749.381356   104.293315    31.185028
# ...

# %%
df.columns
# Out:
# Index(['Area Code', 'Date', 'Market', 'Market Size', 'Product', 'Product Line',
#        'Product Type', 'State', 'Type', 'Budget COGS', 'Budget Margin',
#        'Budget Profit', 'Budget Sales', 'COGS', 'Inventory', 'Margin',
#        'Marketing', 'Profit', 'Sales', 'Total Expenses'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Area Code          int64
# Date               int64
# Market            object
# Market Size       object
# Product           object
# Product Line      object
# Product Type      object
# State             object
# Type              object
# Budget COGS        int64
# Budget Margin      int64
# Budget Profit      int64
# Budget Sales       int64
# COGS               int64
# Inventory          int64
# Margin             int64
# Marketing          int64
# Profit             int64
# Sales              int64
# Total Expenses     int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4248 entries, 0 to 4247
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Area Code       4248 non-null   int64
#  1   Date            4248 non-null   int64
#  2   Market          4248 non-null   object
#  3   Market Size     4248 non-null   object
#  4   Product         4248 non-null   object
#  5   Product Line    4248 non-null   object
#  6   Product Type    4248 non-null   object
#  7   State           4248 non-null   object
#  8   Type            4248 non-null   object
#  9   Budget COGS     4248 non-null   int64
#  10  Budget Margin   4248 non-null   int64
#  11  Budget Profit   4248 non-null   int64
#  12  Budget Sales    4248 non-null   int64
#  13  COGS            4248 non-null   int64
#  14  Inventory       4248 non-null   int64
#  15  Margin          4248 non-null   int64
#  16  Marketing       4248 non-null   int64
# ...

# %% [markdown]
# #### 2) Remove/handle the null values

# %%
df.isnull().sum()
# Out:
# Area Code         0
# Date              0
# Market            0
# Market Size       0
# Product           0
# Product Line      0
# Product Type      0
# State             0
# Type              0
# Budget COGS       0
# Budget Margin     0
# Budget Profit     0
# Budget Sales      0
# COGS              0
# Inventory         0
# Margin            0
# Marketing         0
# Profit            0
# Sales             0
# Total Expenses    0
# dtype: int64

# %% [markdown]
# #### 3) Depict different Market types and their count on a bar chart

# %%
r=df['Market'].value_counts()
r
# Out:
# Central    1344
# West       1344
# East        888
# South       672
# Name: Market, dtype: int64

# %%
plt.bar(r.index,r.values,label='Market count')
plt.xlabel('Market')
plt.ylabel('Count')
plt.legend()
plt.title('Market types and their count')
plt.show()

# %%
r=df.groupby(['Market'])['Market Size'].count()
r
# Out:
# Market
# Central    1344
# East        888
# South       672
# West       1344
# Name: Market Size, dtype: int64

# %%
plt.bar(r.index,r.values,color='orange',label='Market count')
plt.xlabel('Market')
plt.ylabel('Count')
plt.legend()
plt.title('Market types and their count')
plt.show()

# %% [markdown]
# #### 4) Depict different Product types and their count on a line chart

# %%
p=df['Product Type'].value_counts()
p
# Out:
# Espresso      1176
# Coffee        1056
# Herbal Tea    1056
# Tea            960
# Name: Product Type, dtype: int64

# %%
plt.plot(p.index,p.values,label='Product Type count',marker='o',lw=2,linestyle='-.',markersize=10)
plt.xlabel('Product Type')
plt.ylabel('Count')
plt.legend
plt.title('Product types and their count')
plt.show()

# %%
p=df.groupby(['Product Type'])['Product'].count()
p
# Out:
# Product Type
# Coffee        1056
# Espresso      1176
# Herbal Tea    1056
# Tea            960
# Name: Product, dtype: int64

# %%
plt.plot(p.index,p.values,color='orange',label='Product Type count',marker='o',lw=2,linestyle='-.',markersize=10)
plt.xlabel('Product Type')
plt.ylabel('Count')
plt.legend
plt.title('Product types and their count')
plt.show()

# %% [markdown]
# #### 5) Depict different State and their count on a pie chart

# %%
s=df['State'].value_counts()
s
# Out:
# Utah             288
# California       288
# Colorado         264
# Oregon           264
# Nevada           264
# Washington       240
# Florida          216
# Illinois         216
# Wisconsin        216
# Ohio             216
# Missouri         216
# Iowa             216
# New York         192
# Connecticut      168
# New Hampshire    168
# Louisiana        168
# New Mexico       168
# Oklahoma         168
# Texas            168
# Massachusetts    144
# Name: State, dtype: int64

# %%
plt.figure(figsize=(9,9))
plt.pie(s.values,labels=s.index,autopct='%.2f%%')
plt.show()

# %% [markdown]
# #### 6) Depict Market wise sum of Profit and depict the result on bar chart.

# %%
x=df.groupby(['Market'])['Profit'].sum()
x
# Out:
# Market
# Central    93852
# East       59217
# South      32478
# West       73996
# Name: Profit, dtype: int64

# %%
plt.bar(x.index,x.values,color='red',label='Profit sum')
plt.xlabel('Market')
plt.ylabel('Profit sum')
plt.legend()
plt.title('Market wise sum of Profit')
plt.show()

# %% [markdown]
# #### 7) Depict Product wise mean of Sales and depict the result on bar chart and line chart superimposed

# %%
y=df.groupby(['Product'])['Sales'].mean()
y
# Out:
# Product
# Amaretto             136.817708
# Caffe Latte          166.199074
# Caffe Mocha          176.883333
# Chamomile            196.817708
# Colombian            267.314583
# Darjeeling           190.497396
# Decaf Espresso       191.573529
# Decaf Irish Cream    162.104167
# Earl Grey            231.847222
# Green Tea            114.062500
# Lemon                199.845833
# Mint                 185.989583
# Regular Espresso     333.763889
# Name: Sales, dtype: float64

# %%
plt.bar(y.index,y.values,color='green',label='sales avg',width=0.7)
plt.plot(y.index,y.values,color='red',label='line chart')
plt.xlabel('Product')
plt.ylabel('sales avg')
plt.legend()
plt.xticks(rotation=90)
plt.title('Product wise mean of Sales')
plt.show()

# %% [markdown]
# ### 8) Depict Profit vs Sales on a Scatter Chart where Product is 'Regular Espresso'

# %%
d=df[(df['Product']=='Regular Espresso')]
d
# Out:
#       Area Code   Date Market   Market Size           Product Product Line  \
# 74          978  40909   East  Major Market  Regular Espresso        Beans
# 80          603  40909   East  Small Market  Regular Espresso        Beans
# 88          631  40909   East  Major Market  Regular Espresso        Beans
# 251         508  40940   East  Major Market  Regular Espresso        Beans
# 257         603  40940   East  Small Market  Regular Espresso        Beans
# ...         ...    ...    ...           ...               ...          ...
# 3976        603  41579   East  Small Market  Regular Espresso        Beans
# 3985        917  41579   East  Major Market  Regular Espresso        Beans
# 4147        857  41609   East  Major Market  Regular Espresso        Beans
# 4153        603  41609   East  Small Market  Regular Espresso        Beans
# 4162        518  41609   East  Major Market  Regular Espresso        Beans
#
# ...

# %%
plt.figure(figsize=(9,9))
plt.scatter(d['Profit'],d['Sales'],color='maroon',marker='2',label='Profit vs Sales',s=102)
plt.xlabel('Profit')
plt.ylabel('Sales')
plt.legend()
plt.title('Profit vs Sales on a Scatter Chart where Product is Regular Espresso')
plt.show()

# %% [markdown]
# ### 9) Depict Budget Profit vs Budget Sales on a Scatter Chart where State is California and Product is 'Earl Grey'

# %%
d=df[(df['Product']=='Earl Grey') & (df['State']=='California')]
d
# Out:
#       Area Code   Date Market   Market Size    Product Product Line  \
# 140         650  40909   West  Major Market  Earl Grey       Leaves
# 317         858  40940   West  Major Market  Earl Grey       Leaves
# 495         951  40969   West  Major Market  Earl Grey       Leaves
# 674         530  41000   West  Major Market  Earl Grey       Leaves
# 851         530  41030   West  Major Market  Earl Grey       Leaves
# 1027        415  41061   West  Major Market  Earl Grey       Leaves
# 1201        831  41091   West  Major Market  Earl Grey       Leaves
# 1378        310  41122   West  Major Market  Earl Grey       Leaves
# 1555        714  41153   West  Major Market  Earl Grey       Leaves
# 1730        209  41183   West  Major Market  Earl Grey       Leaves
# 1907        650  41214   West  Major Market  Earl Grey       Leaves
# 2084        619  41244   West  Major Market  Earl Grey       Leaves
# 2261        707  41275   West  Major Market  Earl Grey       Leaves
# ...

# %%
d.shape
# Out:
# (24, 20)

# %%
d9=df[(df['State']=='California')& (df['Product']=='Earl Grey')]
d9.shape
# Out:
# (24, 20)

# %%
d9[['Budget Profit','Budget Sales']].drop_duplicates()
# Out:
#       Budget Profit  Budget Sales
# 140              60            90
# 317              60           120
# 495              70           130
# 851              80           140
# 1027             80           150
# 1378             90           160
# 1730             50            80
# 1907             40            80
# 2084             50            90

# %%
d9.shape
# Out:
# (24, 20)

# %%
plt.figure(figsize=(9,9))
plt.scatter(d9['Budget Profit'],d9['Budget Sales'],color='maroon',marker='2',label='Budget Profit vs Budget Sales',s=102)
plt.xlabel('Profit')
plt.ylabel('Sales')
plt.legend()
plt.title('Budget Profit vs Budget Sales on a Scatter Chart where Product is Earl Grey and State is California')
plt.show()

# %%
plt.figure(figsize=(9,9))
plt.scatter(d['Budget Profit'],d['Budget Sales'],color='maroon',marker='2',label='Budget Profit vs Budget Sales',s=102)
plt.xlabel('Profit')
plt.ylabel('Sales')
plt.legend()
plt.title('Budget Profit vs Budget Sales on a Scatter Chart where Product is Earl Grey and State is California')
plt.show()

# %% [markdown]
# ### 10) Depcit Market wise mean of Budget Sales and mean of Sales in a stacked bar chart

# %%
m=df.groupby(['Market'])['Budget Sales'].mean()
m
# Out:
# Market
# Central    186.279762
# East       177.815315
# South      146.130952
# West       178.348214
# Name: Budget Sales, dtype: float64

# %%
n=df.groupby(['Market'])['Sales'].mean()
n
# Out:
# Market
# Central    197.206101
# East       201.099099
# South      154.651786
# West       202.577381
# Name: Sales, dtype: float64

# %%
d=df.groupby(['Market'])['Budget Sales','Sales'].mean()
d
# Out:
# /var/folders/gy/fpmp100s4k3886c9hpxvqcpw0000gn/T/ipykernel_1102/587545808.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   d=df.groupby(['Market'])['Budget Sales','Sales'].mean()
#          Budget Sales       Sales
# Market
# Central    186.279762  197.206101
# East       177.815315  201.099099
# South      146.130952  154.651786
# West       178.348214  202.577381

# %%
plt.bar(d.index,d['Sales'],color='pink',label='mean of sales')
plt.bar(d.index,d['Budget Sales'],color='lightgreen',alpha=0.7,label='mean of budget sales')
plt.xlabel('market')
plt.ylabel('mean of sales/budget sales')
plt.title('market wise mean of sales and budget sales')
plt.legend()
plt.show()

# %% [markdown]
# ### 11) Plot the Frequency distribution of Total Expenses

# %%
x=df['Total Expenses']
x
# Out:
# 0        36
# 1        39
# 2        38
# 3        26
# 4        26
#        ...
# 4243     19
# 4244     57
# 4245     45
# 4246     46
# 4247    125
# Name: Total Expenses, Length: 4248, dtype: int64

# %%
from collections import Counter
c= Counter(x)
print(c)
# Out:
# Counter({45: 140, 46: 138, 17: 108, 38: 103, 39: 98, 19: 98, 54: 95, 37: 89, 40: 88, 16: 88, 55: 87, 43: 87, 25: 85, 20: 81, 44: 77, 36: 76, 42: 75, 41: 72, 51: 63, 26: 61, 58: 60, 53: 58, 33: 58, 69: 58, 49: 57, 63: 55, 27: 54, 56: 54, 35: 53, 21: 52, 47: 51, 59: 50, 61: 49, 48: 44, 24: 42, 52: 41, 28: 41, 34: 41, 32: 41, 64: 40, 30: 40, 11: 40, 18: 39, 57: 39, 22: 38, 87: 37, 91: 34, 15: 33, 66: 33, 65: 33, 68: 32, 77: 30, 90: 29, 60: 29, 50: 28, 70: 28, 62: 28, 29: 27, 72: 26, 113: 26, 76: 26, 23: 24, 94: 24, 115: 24, 71: 23, 116: 23, 96: 23, 12: 22, 146: 18, 31: 18, 86: 17, 85: 17, 143: 17, 109: 16, 88: 16, 83: 15, 114: 15, 73: 15, 67: 14, 117: 14, 125: 12, 74: 12, 121: 12, 127: 11, 129: 11, 78: 11, 142: 11, 110: 10, 126: 10, 112: 10, 147: 10, 99: 10, 93: 10, 84: 10, 95: 10, 102: 9, 131: 9, 89: 9, 98: 8, 79: 8, 108: 8, 92: 8, 97: 7, 135: 7, 130: 7, 75: 7, 100: 7, 152: 6, 149: 6, 107: 6, 144: 6, 101: 5, 124: 5, 132: 5, 133: 5, 141: 5, 128: 4, 145: 4, 119: 4, 134: 4, 111: 4, 178: 4
# ...

# %%
plt.hist(x,color='orange',edgecolor='black')
plt.show()

# %% [markdown]
# ### 12) Compare Frequency Distribution of Profit and Budget Profit on a histogram for the Oregon State

# %%
a=df['Profit'][df['State']=='Oregon']
a
# Out:
# 156      16
# 157      33
# 158      99
# 159      42
# 160      33
#        ...
# 4233     42
# 4234    129
# 4235    -10
# 4236      1
# 4237     37
# Name: Profit, Length: 264, dtype: int64

# %%
b=df['Budget Profit'][df['State']=='Oregon']
b
# Out:
# 156      20
# 157      50
# 158     100
# 159      70
# 160      40
#        ...
# 4233     40
# 4234     80
# 4235     20
# 4236     20
# 4237     50
# Name: Budget Profit, Length: 264, dtype: int64

# %%
plt.hist(a,color='orange',edgecolor='black')
plt.show()
plt.hist(b,color='green',edgecolor='black')
plt.show()

# %%
plt.hist(a,color='orange',edgecolor='black')
plt.hist(b,color='green',edgecolor='black')
plt.show()

# %% [markdown]
# ### 13) Compare Frequency of COGS and Budget COGS on a histogram for the East Market for the Product Caffe Mocha

# %%
c=df[['COGS', 'Budget COGS']][(df['Market']=='East') & (df['Product']=='Caffe Mocha')]
c
# Out:
#       COGS  Budget COGS
# 59      75           70
# 66      79           70
# 75      63           60
# 81      37           30
# 89     105          100
# ...    ...          ...
# 4131    55           50
# 4139   105          100
# 4146    47           40
# 4152    49           40
# 4161   135          130
#
# [120 rows x 2 columns]

# %%
plt.hist(c['COGS'],color='orange',edgecolor='black')
plt.show()
plt.hist(c['Budget COGS'],color='green',edgecolor='black')
plt.show()

# %%
plt.hist(c['COGS'],color='orange',edgecolor='black')
plt.hist(c['Budget COGS'],color='green',edgecolor='black')
plt.show()

# %% [markdown]
# ### 14) Compare Sales vs Profit on a histogram for the Eastern or Central Market and for Decaf Type

# %%
d12 = df[((df['Market']=='East') | (df['Market']=='Central')) & (df['Type']=='Decaf')]
d12.shape
# Out:
# (912, 20)

# %%
plt.hist(d12['Sales'],bins='auto',color='blue',label='Sales')
plt.hist(d12['Profit'],bins='auto',color='maroon',label='Profit')
plt.legend()
plt.show()

# %%
d=df[((df['Market']=='East') | (df['Market']=='Central')) & ((df['Product']=='Decaf Espresso')|(df['Product']=='Decaf Irish Cream'))]
d
# Out:
#       Area Code   Date   Market   Market Size            Product Product Line  \
# 2           970  40909  Central  Major Market  Decaf Irish Cream        Beans
# 5           720  40909  Central  Major Market     Decaf Espresso        Beans
# 12          309  40909  Central  Major Market  Decaf Irish Cream        Beans
# 14          630  40909  Central  Major Market     Decaf Espresso        Beans
# 22          712  40909  Central  Small Market  Decaf Irish Cream        Beans
# ...         ...    ...      ...           ...                ...          ...
# 4123        608  41609  Central  Small Market     Decaf Espresso        Beans
# 4126        414  41609  Central  Small Market  Decaf Irish Cream        Beans
# 4132        203  41609     East  Small Market     Decaf Espresso        Beans
# 4140        386  41609     East  Major Market     Decaf Espresso        Beans
# 4142        727  41609     East  Major Market  Decaf Irish Cream        Beans
#
# ...

# %%
d=df[['Sales','Profit']][((df['Market']=='East') | (df['Market']=='Central')) & ((df['Product']=='Decaf Espresso')|(df['Product']=='Decaf Irish Cream'))]
d
# Out:
#       Sales  Profit
# 2       234     101
# 5       180      53
# 12      234      87
# 14      456     140
# 22       54      12
# ...     ...     ...
# 4123     60      19
# 4126    208      85
# 4132    121      31
# 4140    208      86
# 4142    341     181
#
# [360 rows x 2 columns]

# %%
plt.hist(d['Sales'],color='orange',edgecolor='black')
plt.show()
plt.hist(d['Profit'],color='green',edgecolor='black')
plt.show()

# %% [markdown]
# ### 15) Depict the quartile distribution of COGS where Sales is greater than 400

# %%
x=df[df['Sales']>400]
x
# Out:
#       Area Code   Date   Market   Market Size         Product Product Line  \
# 13          309  40909  Central  Major Market     Caffe Mocha        Beans
# 14          630  40909  Central  Major Market  Decaf Espresso        Beans
# 25          641  40909  Central  Small Market       Chamomile       Leaves
# 27          712  40909  Central  Small Market      Darjeeling       Leaves
# 28          319  40909  Central  Small Market       Earl Grey       Leaves
# ...         ...    ...      ...           ...             ...          ...
# 4212        209  41609     West  Major Market  Decaf Espresso        Beans
# 4214        530  41609     West  Major Market       Colombian        Beans
# 4216        775  41609     West  Small Market      Darjeeling       Leaves
# 4217        775  41609     West  Small Market       Earl Grey       Leaves
# 4220        702  41609     West  Small Market           Lemon       Leaves
#
# ...

# %%
x=df['COGS'][df['Sales']>400]
x
# Out:
# 13      234
# 14      228
# 25      234
# 27      228
# 28      245
#        ...
# 4212    247
# 4214    279
# 4216    247
# 4217    250
# 4220    224
# Name: COGS, Length: 418, dtype: int64

# %%
plt.boxplot(x)
plt.show()

# %% [markdown]
# ### 16) Depict the quartile distribution of Budget Profit for Decaf Espresso

# %%
x=df[df['Product']=='Decaf Espresso']
x
# Out:
#       Area Code   Date   Market   Market Size         Product Product Line  \
# 5           720  40909  Central  Major Market  Decaf Espresso        Beans
# 14          630  40909  Central  Major Market  Decaf Espresso        Beans
# 24          563  40909  Central  Small Market  Decaf Espresso        Beans
# 33          660  40909  Central  Small Market  Decaf Espresso        Beans
# 42          614  40909  Central  Major Market  Decaf Espresso        Beans
# ...         ...    ...      ...           ...             ...          ...
# 4200        435  41609     West  Small Market  Decaf Espresso        Beans
# 4212        209  41609     West  Major Market  Decaf Espresso        Beans
# 4224        775  41609     West  Small Market  Decaf Espresso        Beans
# 4234        971  41609     West  Small Market  Decaf Espresso        Beans
# 4245        360  41609     West  Small Market  Decaf Espresso        Beans
#
#      Product Type       State   Type  Budget COGS  Budget Margin  \
# ...

# %%
x=df['Budget Profit'][df['Product']=='Decaf Espresso']
x
# Out:
# 5        80
# 14      180
# 24       30
# 33       60
# 42       40
#        ...
# 4200     50
# 4212    210
# 4224     20
# 4234     80
# 4245     60
# Name: Budget Profit, Length: 408, dtype: int64

# %%
plt.boxplot(x)
plt.show()

# %% [markdown]
# ### 17) Find the Market, Product and Type where Sales is maximum

# %%
x=df[['Market','Product','Product Type']][df['Sales']==df['Sales'].max()]
x
# Out:
#      Market    Product Product Type
# 1154   East  Colombian       Coffee
# 1196   West  Colombian       Coffee

# %%
x=df[df['Sales']==df['Sales'].max()]
x
# Out:
#       Area Code   Date Market   Market Size    Product Product Line  \
# 1154        845  41091   East  Major Market  Colombian        Beans
# 1196        707  41091   West  Major Market  Colombian        Beans
#
#      Product Type       State     Type  Budget COGS  Budget Margin  \
# 1154       Coffee    New York  Regular          340            520
# 1196       Coffee  California  Regular          450            690
#
#       Budget Profit  Budget Sales  COGS  Inventory  Margin  Marketing  Profit  \
# 1154            370           860   364       2654     548        127     370
# 1196            530          1140   364       2654     548        127     370
#
#       Sales  Total Expenses
# 1154    912             178
# 1196    912             178

# %% [markdown]
# ### 18) Find State and Market with Maximum Profit or Maximum Budget Profit

# %%
x=df[['Market','State']][(df['Profit']==df['Profit'].max()) | (df['Budget Profit']==df['Budget Profit'].max())]
x
# Out:
#      Market          State
# 1139   East  Massachusetts
# 1316   East  Massachusetts
# 3263   East  Massachusetts
# 3440   East  Massachusetts

# %%
x=df[(df['Profit']==df['Profit'].max()) | (df['Budget Profit']==df['Budget Profit'].max())]
x
# Out:
#       Area Code   Date Market   Market Size    Product Product Line  \
# 1139        508  41091   East  Major Market  Colombian        Beans
# 1316        508  41122   East  Major Market  Colombian        Beans
# 3263        978  41456   East  Major Market  Colombian        Beans
# 3440        617  41487   East  Major Market  Colombian        Beans
#
#      Product Type          State     Type  Budget COGS  Budget Margin  \
# 1139       Coffee  Massachusetts  Regular           40            590
# 1316       Coffee  Massachusetts  Regular           40            590
# 3263       Coffee  Massachusetts  Regular           40            590
# 3440       Coffee  Massachusetts  Regular           40            590
#
#       Budget Profit  Budget Sales  COGS  Inventory  Margin  Marketing  Profit  \
# 1139            560           630    52      -1493     613         17     564
# 1316            560           630    52      -2033     612         17     563
# ...

# %%
x=df[['Market','State']][df['Profit']==df['Profit'].max()]
x
# Out:
#      Market          State
# 3263   East  Massachusetts

# %%
x=df[['Market','State']][df['Budget Profit']==df['Budget Profit'].max()]
x
# Out:
#      Market          State
# 1139   East  Massachusetts
# 1316   East  Massachusetts
# 3263   East  Massachusetts
# 3440   East  Massachusetts

# %% [markdown]
# ### 19) Find Product, State and Market where Total Expenses are minimum

# %%
x=df[['Product','State','Market']][df['Total Expenses']==df['Total Expenses'].min()]
x
# Out:
#           Product          State Market
# 2910    Green Tea  New Hampshire   East
# 3087    Green Tea  New Hampshire   East
# 3339  Caffe Latte         Nevada   West
# 3516  Caffe Latte         Nevada   West

# %%
x=df[df['Total Expenses']==df['Total Expenses'].min()]
x
# Out:
#       Area Code   Date Market   Market Size      Product Product Line  \
# 2910        603  41395   East  Small Market    Green Tea       Leaves
# 3087        603  41426   East  Small Market    Green Tea       Leaves
# 3339        775  41456   West  Small Market  Caffe Latte        Beans
# 3516        775  41487   West  Small Market  Caffe Latte        Beans
#
#      Product Type          State     Type  Budget COGS  Budget Margin  \
# 2910          Tea  New Hampshire  Regular            0             40
# 3087          Tea  New Hampshire  Regular            0             40
# 3339     Espresso         Nevada  Regular            0             40
# 3516     Espresso         Nevada  Regular            0             40
#
#       Budget Profit  Budget Sales  COGS  Inventory  Margin  Marketing  Profit  \
# 2910             30            40     0        645      43          0      44
# 3087             30            40     0        602      43          0      44
# ...

# %% [markdown]
# ### 20) Statisically infer the State, Product and Market chosen to further expand/invest into the Coffee Business based on Sales, Profit and Total Expenses

# %%
max_sale = df['Sales'].max()
max_profit = df['Profit'].max()
min_te = df['Total Expenses'].min()
print(max_sale,max_profit,min_te)
# Out:
# 912 778 10

# %%
d18 = df[(df['Sales']==912) | (df['Profit']==778) | (df['Total Expenses']==10)]
d18.shape
# Out:
# (7, 20)

# %%
d18[['State','Market','Product','Type','Sales','Profit','Total Expenses']]
# Out:
#               State Market      Product     Type  Sales  Profit  \
# 1154       New York   East    Colombian  Regular    912     370
# 1196     California   West    Colombian  Regular    912     370
# 2910  New Hampshire   East    Green Tea  Regular     43      44
# 3087  New Hampshire   East    Green Tea  Regular     43      44
# 3263  Massachusetts   East    Colombian  Regular    659     778
# 3339         Nevada   West  Caffe Latte  Regular     43      44
# 3516         Nevada   West  Caffe Latte  Regular     43      44
#
#       Total Expenses
# 1154             178
# 1196             178
# 2910              10
# 3087              10
# 3263              46
# 3339              10
# 3516              10

# %%
x=df[['Product','State','Market']][((df['Profit']==df['Profit'].max()) | (df['Sales']==df['Sales'].max()) & (df['Total Expenses']==df['Total Expenses'].min()))]
x
# Out:
#         Product          State Market
# 3263  Colombian  Massachusetts   East

# %%
x=df[['Product','State','Market']][((df['Profit']==df['Profit'].max()) | (df['Sales']==df['Sales'].max()) | (df['Total Expenses']==df['Total Expenses'].min()))]
x
# Out:
#           Product          State Market
# 1154    Colombian       New York   East
# 1196    Colombian     California   West
# 2910    Green Tea  New Hampshire   East
# 3087    Green Tea  New Hampshire   East
# 3263    Colombian  Massachusetts   East
# 3339  Caffe Latte         Nevada   West
# 3516  Caffe Latte         Nevada   West

# %% [markdown]
# ### 21) Statisically infer the State, Product and Market chosen to further withhold the Coffee Business based on Sales, Profit and Total Expenses.

# %%
min_sale = df['Sales'].min()
min_profit = df['Profit'].min()
max_te = df['Total Expenses'].max()
print(min_sale,min_profit,max_te)
# Out:
# 17 -638 190

# %%
d19 = df[(df['Sales']==17) | (df['Profit']==-638) | (df['Total Expenses']==190)]
d19.shape
# Out:
# (3, 20)

# %%
d19[['State','Market','Product','Type','Sales','Profit','Total Expenses']]
# Out:
#        State Market    Product     Type  Sales  Profit  Total Expenses
# 154   Nevada   West  Green Tea  Regular     17    -354             126
# 1385  Nevada   West  Chamomile    Decaf    412      49             190
# 3687  Nevada   West  Green Tea  Regular     20    -638             147

# %%
x=df[['Product','State','Market']][((df['Profit']==df['Profit'].min()) | (df['Sales']==df['Sales'].min()) & (df['Total Expenses']==df['Total Expenses'].max()))]
x
# Out:
#         Product   State Market
# 3687  Green Tea  Nevada   West

# %%
x=df[['Product','State','Market']][((df['Profit']==df['Profit'].min()) | (df['Sales']==df['Sales'].min()) | (df['Total Expenses']==df['Total Expenses'].max()))]
x
# Out:
#         Product   State Market
# 154   Green Tea  Nevada   West
# 1385  Chamomile  Nevada   West
# 3687  Green Tea  Nevada   West

# %% [markdown]
# ## Pandas Plots

# %% [markdown]
# ### 22) Depict Market and Type wise sum of Budget Profit on a bar chart

# %%
x=df.groupby(['Market','Type'])['Budget Profit'].sum()
x
# Out:
# Market   Type
# Central  Decaf      43880
#          Regular    48700
# East     Decaf      10800
#          Regular    45980
# South    Decaf      16320
#          Regular    18720
# West     Decaf      36240
#          Regular    38120
# Name: Budget Profit, dtype: int64

# %%
x.plot(kind='bar')
plt.show()

# %% [markdown]
# ### 23) Depict Product Type and State wise mean of Sales on a area chart

# %%
x=df.groupby(['State','Product Type'])['Sales'].mean()
x
# Out:
# State       Product Type
# California  Coffee          343.027778
#             Espresso        476.375000
#             Herbal Tea      315.569444
#             Tea             210.750000
# Colorado    Coffee          229.819444
#                                ...
# Washington  Tea             135.888889
# Wisconsin   Coffee          194.152778
#             Espresso        133.645833
#             Herbal Tea      132.687500
#             Tea             131.375000
# Name: Sales, Length: 76, dtype: float64

# %%
plt.figure(figsize=(10,10))
x.plot(kind='area')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 24) Depict Product and Type wise sum of Budget COGS on a line Chart

# %%
x=df.groupby(['Product','Type'])['Budget COGS'].sum()
x
# Out:
# Product            Type
# Amaretto           Regular    13420
# Caffe Latte        Regular    12820
# Caffe Mocha        Regular    36820
# Chamomile          Decaf      25360
# Colombian          Regular    51240
# Darjeeling         Regular    22880
# Decaf Espresso     Decaf      31660
# Decaf Irish Cream  Decaf      32220
# Earl Grey          Regular    21040
# Green Tea          Regular    13220
# Lemon              Decaf      32560
# Mint               Decaf      15140
# Regular Espresso   Regular     9500
# Name: Budget COGS, dtype: int64

# %%
x.plot(kind='line')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 25) Depict Product and Type wise sum of Budget Profit and Budget Sales on a line Chart

# %%
x=df.groupby(['Product','Type'])[['Budget Profit','Budget Sales']].sum()
x
# Out:
#                            Budget Profit  Budget Sales
# Product           Type
# Amaretto          Regular           7020         27200
# Caffe Latte       Regular          10100         30540
# Caffe Mocha       Regular          23280         84600
# Chamomile         Decaf            24920         63840
# Colombian         Regular          57800        134380
# Darjeeling        Regular          22860         57360
# Decaf Espresso    Decaf            29460         75720
# Decaf Irish Cream Decaf            19060         67040
# Earl Grey         Regular          17600         50900
# Green Tea         Regular           3800         25340
# Lemon             Decaf            27020         78300
# Mint              Decaf             6780         28320
# Regular Espresso  Regular           9060         22620

# %%
x.plot(kind='line')
plt.xticks(rotation=90)
plt.show()
x.plot(kind='bar')
plt.xticks(rotation=90)
plt.show()
x.plot(kind='bar',stacked=True)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 26) Depict Market and Product Type based mean of Sales on abar chart and on a stacked bar chart separately

# %%
x=df.groupby(['Market','Product Type'])['Sales'].mean()
x
# Out:
# Market   Product Type
# Central  Coffee          179.895833
#          Espresso        207.295139
#          Herbal Tea      202.047619
#          Tea             203.500000
# East     Coffee          337.148810
#          Espresso        201.654167
#          Herbal Tea      191.486111
#          Tea             121.882576
# South    Coffee          173.223958
#          Espresso        156.215278
#          Herbal Tea      133.734375
# West     Coffee          185.410256
#          Espresso        194.188889
#          Herbal Tea      231.692308
#          Tea             200.611111
# Name: Sales, dtype: float64

# %%
x.plot(kind='bar')
plt.xticks(rotation=90)
plt.show()

# %%
y=x.unstack()
y
# Out:
# Product Type      Coffee    Espresso  Herbal Tea         Tea
# Market
# Central       179.895833  207.295139  202.047619  203.500000
# East          337.148810  201.654167  191.486111  121.882576
# South         173.223958  156.215278  133.734375         NaN
# West          185.410256  194.188889  231.692308  200.611111

# %%
y.plot(kind='bar')
plt.xticks(rotation=90)
plt.show()

# %%
x.unstack().plot(kind='bar',stacked=True)
plt.xticks(rotation=90)
plt.grid()
plt.show() # values added on top of one another not merged

# %% [markdown]
# ### Extra

# %%
s1=[1,2,3,4,5]
s2=[13,17,11,16,18]
plt.bar(s1,s2,color='orange')
for i in range(len(s1)):
    plt.annotate(xy=[s1[i]-0.1,s2[i]+0.3],text=s2[i])
plt.show()

# %%
s1=[1,2,3,4,5]
s2=[13,17,11,16,18]
plt.bar(s1,s2,color='orange')
for i in range(len(s1)):
    plt.annotate(xy=[s1[i]-0.3,s2[i]+0.3],text=(s1[i],s2[i]))
plt.show()

# %% [markdown]
# ### 27) Find State and Market Size based mean of Sales and COGS where Market is not Central and Profit is over 350. Depict the result on a line chart, stacked bar and area chart separately

# %%
d=df[((df['Market']!='Central') & (df['Profit']>350)) ]
d
# Out:
#       Area Code   Date Market   Market Size           Product Product Line  \
# 76          413  40909   East  Major Market         Colombian        Beans
# 430         978  40969   East  Major Market         Colombian        Beans
# 607         774  41000   East  Major Market         Colombian        Beans
# 784         978  41030   East  Major Market         Colombian        Beans
# 961         617  41061   East  Major Market         Colombian        Beans
# ...         ...    ...    ...           ...               ...          ...
# 4148        351  41609   East  Major Market         Colombian        Beans
# 4156        631  41609   East  Major Market             Lemon       Leaves
# 4162        518  41609   East  Major Market  Regular Espresso        Beans
# 4163        315  41609   East  Major Market         Colombian        Beans
# 4214        530  41609   West  Major Market         Colombian        Beans
#
# ...

# %%
x=d.groupby(['State','Market Size'])[['Sales','Budget COGS']].mean()
x
# Out:
#                                  Sales  Budget COGS
# State         Market Size
# California    Major Market  794.125000   378.750000
# Massachusetts Major Market  566.809524    54.285714
# Nevada        Small Market  676.500000   190.000000
# New York      Major Market  770.461538   254.615385

# %%
x.plot(kind='line',marker='o')
plt.xticks(rotation=90)
plt.show()
x.plot(kind='bar',stacked=True)
plt.xticks(rotation=90)
plt.show()
x.plot(kind='area')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 28) Find Product and Market Size based mean of Budget COGS and Inventory where Type is Regular and neither product or its Type is Espresso. Depict the result on a line chart, stacked bar and area chart separately

# %%
df['Product Type'].value_counts()
# Out:
# Espresso      1176
# Coffee        1056
# Herbal Tea    1056
# Tea            960
# Name: Product Type, dtype: int64

# %%
d=df[((df['Type']=='Regular') & ((df['Product']!='Regular Espresso') & (df['Product Type']!='Espresso'))) ]
d
# Out:
#       Area Code   Date   Market   Market Size     Product Product Line  \
# 0           719  40909  Central  Major Market    Amaretto        Beans
# 1           970  40909  Central  Major Market   Colombian        Beans
# 3           303  40909  Central  Major Market   Green Tea       Leaves
# 9           719  40909  Central  Major Market  Darjeeling       Leaves
# 10          303  40909  Central  Major Market   Earl Grey       Leaves
# ...         ...    ...      ...           ...         ...          ...
# 4236        541  41609     West  Small Market   Colombian        Beans
# 4238        253  41609     West  Small Market  Darjeeling       Leaves
# 4239        253  41609     West  Small Market   Earl Grey       Leaves
# 4240        509  41609     West  Small Market   Green Tea       Leaves
# 4246        360  41609     West  Small Market   Colombian        Beans
#
#      Product Type       State     Type  Budget COGS  Budget Margin  \
# ...

# %%
x=d.groupby(['Product','Market Size'])[['Inventory','Budget COGS']].mean()
x
# Out:
#                            Inventory  Budget COGS
# Product    Market Size
# Amaretto   Major Market   981.750000   103.888889
#            Small Market   596.583333    49.500000
# Colombian  Major Market   905.020833   171.354167
#            Small Market   575.902778    63.680556
# Darjeeling Major Market   734.380952    57.619048
#            Small Market   740.518519    61.111111
# Earl Grey  Major Market   726.783333    66.833333
#            Small Market   778.880952    77.500000
# Green Tea  Major Market   608.416667    44.000000
#            Small Market  1108.916667    47.261905

# %%
x.plot(kind='line')
plt.xticks(rotation=90)
plt.show()
x.plot(kind='bar',stacked=True)
plt.xticks(rotation=90)
plt.show()
x.plot(kind='area')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Seaborn EDA

# %% [markdown]
# ### 1) Depict Product based on Market Size on a count plot

# %%
sns.countplot(x=df['Product'],hue=df['Market Size'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 2) Depict State based on Market on a count plot

# %%
sns.countplot(x=df['State'],hue=df['Market'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 3) Depict the Product Type vs Total Expenses on a Violin Plot based on Market

# %%
plt.figure(figsize=(10,10))
sns.violinplot(x=df['Product Type'],y=df['Total Expenses'],hue=df['Market'])
plt.show()

# %% [markdown]
# ### 4) Depict Market vs Budget COGS on a boxplot

# %%
sns.boxplot(x=df['Market'],y=df['Budget COGS'])
plt.show()

# %% [markdown]
# ### 5) Depict Product vs Margin on a boxplot based on Market Size

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x=df['Product'],y=df['Margin'],hue=df['Market Size'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 6) Depict the Market vs Budget Sales on a Violin Plot based on Product Type where product is Colombina or Darjeeling

# %%
d=df[(df['Product']=='Colombian') |(df['Product']=='Darjeeling')]
d
# Out:
#       Area Code   Date   Market   Market Size     Product Product Line  \
# 1           970  40909  Central  Major Market   Colombian        Beans
# 9           719  40909  Central  Major Market  Darjeeling       Leaves
# 11          217  40909  Central  Major Market   Colombian        Beans
# 18          217  40909  Central  Major Market  Darjeeling       Leaves
# 21          641  40909  Central  Small Market   Colombian        Beans
# ...         ...    ...      ...           ...         ...          ...
# 4225        702  41609     West  Small Market   Colombian        Beans
# 4227        541  41609     West  Small Market  Darjeeling       Leaves
# 4236        541  41609     West  Small Market   Colombian        Beans
# 4238        253  41609     West  Small Market  Darjeeling       Leaves
# 4246        360  41609     West  Small Market   Colombian        Beans
#
#      Product Type       State     Type  Budget COGS  Budget Margin  \
# ...

# %%
d['Product'].value_counts()
# Out:
# Colombian     480
# Darjeeling    384
# Name: Product, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.violinplot(x=d['Market'],y=df['Budget Sales'],hue=d['Product Type'])
plt.show()

# %% [markdown]
# ### 7) Depict the Product vs Inventory on a Box Plot based on Product Type where State is California or Nevada

# %%
d=df[(df['State']=='California') |(df['State']=='Nevada')]
d
# Out:
#       Area Code   Date Market   Market Size            Product Product Line  \
# 133         661  40909   West  Major Market        Caffe Latte        Beans
# 134         818  40909   West  Major Market        Caffe Mocha        Beans
# 135         213  40909   West  Major Market     Decaf Espresso        Beans
# 136         510  40909   West  Major Market          Chamomile       Leaves
# 137         310  40909   West  Major Market              Lemon       Leaves
# ...         ...    ...    ...           ...                ...          ...
# 4222        775  41609   West  Small Market        Caffe Latte        Beans
# 4223        775  41609   West  Small Market        Caffe Mocha        Beans
# 4224        775  41609   West  Small Market     Decaf Espresso        Beans
# 4225        702  41609   West  Small Market          Colombian        Beans
# 4226        775  41609   West  Small Market  Decaf Irish Cream        Beans
#
# ...

# %%
d['State'].value_counts()
# Out:
# California    288
# Nevada        264
# Name: State, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x=d['Product'],y=df['Inventory'],hue=d['Product Type'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 8) Generate Pairplot for the Coffee dataset where Type is Regular including fields- Budget Sales, Budget Profit, Budget COGS, Sales, Proift and COGS

# %%
d=df[['Budget Sales', 'Budget Profit', 'Budget COGS', 'Sales', 'Profit' ,'COGS']][(df['Type']=='Regular')]
d
# Out:
#       Budget Sales  Budget Profit  Budget COGS  Sales  Profit  COGS
# 0              220            100           90    219      94    89
# 1              190             80           80    190      68    83
# 3               80             30           30    100      30    44
# 4              150             70           60    134      54    54
# 9              110             20           40    130      17    58
# ...            ...            ...          ...    ...     ...   ...
# 4239            70             20           30    113      42    43
# 4240            90            -10           40    140      -4    55
# 4243            50             20           20     60      19    24
# 4244           140             30           60    155      34    65
# 4246           200             80           80    188      86    72
#
# [2400 rows x 6 columns]

# %%
sns.pairplot(d)
plt.show()

# %% [markdown]
# ### 9) Generate Pairplot for the Coffee dataset where Profit is over 250 based on Type including fields- Budget Sales, Budget Profit, Budget COGS, Sales, Proift and COGS

# %%
d=df[['Budget Sales', 'Budget Profit', 'Budget COGS', 'Sales', 'Profit' ,'COGS','Type']][(df['Profit']>250)]
d
# Out:
#       Budget Sales  Budget Profit  Budget COGS  Sales  Profit  COGS     Type
# 76             460            360           60    494     367    72  Regular
# 90             640            260          260    678     262   271  Regular
# 143            840            370          340    678     262   271  Regular
# 253            440            330           70    470     340    75  Regular
# 265            560            280          210    580     264   228  Regular
# ...            ...            ...          ...    ...     ...   ...      ...
# 4208           480            170          220    559     279   241    Decaf
# 4212           550            210          240    614     321   247    Decaf
# 4214           830            350          330    745     402   279  Regular
# 4216           420            150          180    614     319   247  Regular
# 4220           490            170          210    569     288   224    Decaf
#
# [181 rows x 7 columns]

# %%
sns.pairplot(data=d, hue='Type')
plt.show()

# %% [markdown]
# ### 10) Generate Pairplot for the Coffee dataset where Market is Western or Central based and Product Line is beans based on Type including fields- COGS, Sales, Proift and Total Expenses

# %%
d=df[['COGS', 'Sales', 'Profit','Total Expenses','Type']][((df['Market']=='West')| (df['Market']=='Central')) & (df['Product Line']=='Beans')]
d
# Out:
#       COGS  Sales  Profit  Total Expenses     Type
# 0       89    219      94              36  Regular
# 1       83    190      68              39  Regular
# 2       95    234     101              38    Decaf
# 4       54    134      54              26  Regular
# 5       72    180      53              55    Decaf
# ...    ...    ...     ...             ...      ...
# 4243    24     60      19              19  Regular
# 4244    65    155      34              57  Regular
# 4245    80    188      76              45    Decaf
# 4246    72    188      86              46  Regular
# 4247   105    266      30             125    Decaf
#
# [1344 rows x 5 columns]

# %%
sns.pairplot(data=d, hue='Type')
plt.show()

# %% [markdown]
# ### 11) Depict Product vs Sales based on Market on a Strip Plot where Type is Decaf and Market is not Central

# %%
d=df[['Product','Sales','Market','Type']][((df['Type']=='Decaf')&(df['Market']!='Central'))]
d
# Out:
#                 Product  Sales Market   Type
# 58       Decaf Espresso    130   East  Decaf
# 61                Lemon    190   East  Decaf
# 62                 Mint    170   East  Decaf
# 65       Decaf Espresso    180   East  Decaf
# 67    Decaf Irish Cream    200   East  Decaf
# ...                 ...    ...    ...    ...
# 4237  Decaf Irish Cream    108   West  Decaf
# 4241          Chamomile    308   West  Decaf
# 4242              Lemon    128   West  Decaf
# 4245     Decaf Espresso    188   West  Decaf
# 4247  Decaf Irish Cream    266   West  Decaf
#
# [1224 rows x 4 columns]

# %%
plt.figure(figsize=(10,10))
sns.stripplot(x=d['Product'],y=d['Sales'],hue=d['Market'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 12) Depict State vs Budget Profit based on Product Type on a Strip Plot where Market is not Western and Sales >300

# %%
d=df[['State','Budget Profit','Market','Product Type','Sales']][((df['Sales']>300)&(df['Market']!='West'))]
d
# Out:
#          State  Budget Profit   Market Product Type  Sales
# 6     Colorado            110  Central   Herbal Tea    341
# 11    Illinois            130  Central       Coffee    345
# 13    Illinois            260  Central     Espresso    546
# 14    Illinois            180  Central     Espresso    456
# 25        Iowa            200  Central   Herbal Tea    546
# ...        ...            ...      ...          ...    ...
# 4162  New York            320     East     Espresso    700
# 4163  New York            250     East       Coffee    745
# 4182  Oklahoma             90    South     Espresso    341
# 4187     Texas            240    South       Coffee    559
# 4190     Texas            110    South     Espresso    322
#
# [417 rows x 5 columns]

# %%
plt.figure(figsize=(10,10))
sns.stripplot(x=d['State'],y=d['Budget Profit'],hue=d['Product Type'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 13) Depict Market vs Total Expenses based on Type on a Swarm Plot where Sales is over 200 and Market Size is Small

# %%
d=df[['Total Expenses','Market Size','Market','Type','Sales','Market Size']][((df['Sales']>200)&(df['Market Size']=='Small Market'))]
d
# Out:
#       Total Expenses   Market Size   Market     Type  Sales   Market Size
# 25               110  Small Market  Central    Decaf    546  Small Market
# 26                53  Small Market  Central    Decaf    234  Small Market
# 27                87  Small Market  Central  Regular    456  Small Market
# 28               126  Small Market  Central  Regular    546  Small Market
# 60                71  Small Market     East  Regular    310  Small Market
# ...              ...           ...      ...      ...    ...           ...
# 4228              60  Small Market     West  Regular    236  Small Market
# 4229              65  Small Market     West  Regular    341  Small Market
# 4234              66  Small Market     West    Decaf    326  Small Market
# 4241              69  Small Market     West    Decaf    308  Small Market
# 4247             125  Small Market     West    Decaf    266  Small Market
#
# [506 rows x 6 columns]

# %%
plt.figure(figsize=(9,9))
sns.swarmplot(x=d['Market'],y=d['Total Expenses'],hue=d['Type'])
plt.show()

# %% [markdown]
# ### 14) Depict correlation values on a heatmap

# %%
df1=df.copy()
df1.drop(['Area Code','Date'],axis=1, inplace=True)
df1.head(2)

# %%
corr=df1.corr()
print(corr)
# Out:
#                 Budget COGS  Budget Margin  Budget Profit  Budget Sales  \
# Budget COGS        1.000000       0.750422       0.579176      0.911598
# Budget Margin      0.750422       1.000000       0.949637      0.955792
# Budget Profit      0.579176       0.949637       1.000000      0.848285
# Budget Sales       0.911598       0.955792       0.848285      1.000000
# COGS               0.947762       0.688587       0.514967      0.849901
# Inventory          0.579876       0.119373      -0.019275      0.332216
# Margin             0.680549       0.963460       0.922812      0.901981
# Marketing          0.773709       0.543039       0.279315      0.681946
# Profit             0.479862       0.876844       0.937606      0.758830
# Sales              0.862882       0.920757       0.815435      0.956538
# Total Expenses     0.744259       0.530776       0.255811      0.661217
#
#                     COGS  Inventory    Margin  Marketing    Profit     Sales  \
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# ### 15) Depict Budget Sales vs Sales on a Joint Plot

# %%
sns.jointplot(x=df['Budget Sales'],y=df['Sales'],color='green')
plt.show()

# %% [markdown]
# ### 16) Depict Total Expenses on Joint plot where Sales>300 or Profit>300 where joint plot kind is scatter

# %%
d=df[((df['Sales']>300)|(df['Profit']>300))]
d
# Out:
#        Market   Market Size         Product Product Line Product Type  \
# 6     Central  Major Market       Chamomile       Leaves   Herbal Tea
# 11    Central  Major Market       Colombian        Beans       Coffee
# 13    Central  Major Market     Caffe Mocha        Beans     Espresso
# 14    Central  Major Market  Decaf Espresso        Beans     Espresso
# 25    Central  Small Market       Chamomile       Leaves   Herbal Tea
# ...       ...           ...             ...          ...          ...
# 4220     West  Small Market           Lemon       Leaves   Herbal Tea
# 4221     West  Small Market            Mint       Leaves   Herbal Tea
# 4229     West  Small Market       Green Tea       Leaves          Tea
# 4234     West  Small Market  Decaf Espresso        Beans     Espresso
# 4241     West  Small Market       Chamomile       Leaves   Herbal Tea
#
#            State     Type  Budget COGS  Budget Margin  Budget Profit  \
# ...

# %%
sns.jointplot(x=d['Total Expenses'],y=d['Sales'],kind='scatter',color='orange')
plt.show()

# %%
sns.jointplot(x=d['Total Expenses'],y=d['Profit'],kind='scatter',color='blue')
plt.show()

# %%
dw1 = df[(df['Sales']>300) | (df['Profit']>300)]
dw1.shape
# Out:
# (674, 18)

# %%
plt.figure(figsize=(10,10))
sns.jointplot(x=np.arange(1,675),y=dw1['Total Expenses'],color='blue',kind='scatter')
# kind = scatter, hex, reg,kde
# plt.xlabel('')
plt.ylabel('Total Expenses')
plt.title('Total expenses Joint Plot')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 17) Depict Budget COGS on Joint plot where Market is Eastern and Type is Regular where joint plot kind is hex

# %%
d=df[((df['Market']=='East')&(df['Type']=='Regular'))]
d
# Out:
#      Market   Market Size           Product Product Line Product Type  \
# 56     East  Small Market        Darjeeling       Leaves          Tea
# 57     East  Small Market         Green Tea       Leaves          Tea
# 59     East  Small Market       Caffe Mocha        Beans     Espresso
# 60     East  Small Market         Colombian        Beans       Coffee
# 63     East  Major Market        Darjeeling       Leaves          Tea
# ...     ...           ...               ...          ...          ...
# 4159   East  Major Market         Earl Grey       Leaves          Tea
# 4160   East  Major Market         Green Tea       Leaves          Tea
# 4161   East  Major Market       Caffe Mocha        Beans     Espresso
# 4162   East  Major Market  Regular Espresso        Beans     Espresso
# 4163   East  Major Market         Colombian        Beans       Coffee
#
#             State     Type  Budget COGS  Budget Margin  Budget Profit  \
# ...

# %%
sns.jointplot(x=d['Budget COGS'],y=d['COGS'],kind='hex',color='blue')
plt.show()

# %%
dw2 = df[(df['Market']=='East') & (df['Type']=='Regular')]
print(dw2.shape)
# Out:
# (600, 18)

# %%
plt.figure(figsize=(10,10))
sns.jointplot(x=np.arange(1,601),y=dw2['Budget COGS'],color='red',kind='hex')
# kind = scatter, hex, kde
# plt.xlabel('')
plt.ylabel('Budget COGS')
plt.title('Budget COGS Joint Plot')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 18) Depict Marketing on Joint plot where Market is not Central and Sales is over 500 where joint plot type is kde

# %%
dw3 = df[(df['Market']!='Central') & (df['Sales']>500)]
dw3.shape
# Out:
# (225, 18)

# %%
plt.figure(figsize=(10,10))
sns.jointplot(x=np.arange(1,226),y=dw3['Marketing'],color='green',kind='kde')
# kind = scatter, hex, kde
# plt.xlabel('')
plt.ylabel('Marketing')
plt.title('Marketing Joint Plot')
plt.xticks(rotation=90)
plt.show()
